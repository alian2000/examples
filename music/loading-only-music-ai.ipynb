# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import joblib

# %%
model=joblib.load('saved-music-recommender.joblib')
predictions=model.predict([ [21,1], [22,0]])
predictions
# Out:
# C:\Users\salian\Documents\python\face12\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)
