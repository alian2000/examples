# %%
import pandas as pd
from sklearn import tree
import numpy as np


music_data=pd.read_csv('music-extended.csv.')
#print(music_data.shape)
# print("---------shape----------------")
# print(music_data.describe())
# print("----------describe---------------")

#music_data.head(22)

# %%
#from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()


y=music_data['genre']
print(y)
print("-------------------------------------------------------------------------------------------------------")

music_data["genre"].unique()
music_data["genre"].value_counts()

music_data_encoded=label_encoder.fit_transform(y)

print("music_data_encoded= ",music_data_encoded)
print("-------------------------------------------------------------------------------------------------------")
decoded = label_encoder.inverse_transform(music_data_encoded)
#print("decoded ",decoded)
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# 18          Pop
# 19          Pop
# 20          Pop
# 21          Pop
# Name: genre, dtype: object
# -------------------------------------------------------------------------------------------------------
# music_data_encoded=  [3 3 3 4 4 4 1 1 1 2 2 2 0 0 0 1 1 1 5 5 5 5]
# -------------------------------------------------------------------------------------------------------

# %%
dictionary = dict(zip(music_data_encoded, decoded))

print(dictionary)
print("Length of dictionary:", len(dictionary))
# Out:
# {3: 'HipHop', 4: 'Jazz', 1: 'Classical', 2: 'Dance', 0: 'Acoustic', 5: 'Pop'}
# Length of dictionary: 6

# %%
from sklearn.tree import DecisionTreeRegressor
X=music_data.drop(columns=['genre'])
#y=music_data['genre']
y=music_data_encoded



model2 = DecisionTreeRegressor(random_state=42)

#print(X)
#print(y)
model2.fit(X,y)



#predictions=model.predict([ [21,1], [22,0]])
predictions=model2.predict([[20,0]])
print("prediction_label_encoder",int(predictions))
value = dictionary.get(int(predictions))

print(f"The value associated with the key '{predictions}' is {value}.")
print("----------------------------------")
#####print(decoded[int(predictions)])
#decoded = label_encoder.inverse_transform(music_data["genre"][int(predictions)])
#print(decoded)

#print("decoded_label_prediction= ",label_encoder.fit_transform(3.))
# Out:
# prediction_label_encoder 2
# The value associated with the key '[2.]' is Dance.
# ----------------------------------
# C:\Users\salian\Documents\python\face12\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print(type(decoded))
print(np.unique(decoded))

tree.export_graphviz(model2, out_file='music-ai-label-encoder.dot',
                     feature_names=['age','gender'],
                     class_names=sorted(np.unique(decoded)),
                     label='all',
                     rounded=True,
                     filled=True)
# Out:
# <class 'numpy.ndarray'>
# ['Acoustic' 'Classical' 'Dance' 'HipHop' 'Jazz' 'Pop']
